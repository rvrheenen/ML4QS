# %%
# %matplotlib inline

# %%
# IMPORTS
from Chapter2.CreateDataset import CreateDataset
from util.VisualizeDataset import VisualizeDataset
from util import util
import copy
import os
import pandas as pd
import matplotlib.pyplot as plt
import sys
import warnings

# %%
# CONSTANTS
DATASETS_FOLDER_NAME = 'datasets/'
DATASET_NAME = 'magnetometer4045.csv'
DATASETS_FOLDER_PATH = os.path.join('..', DATASETS_FOLDER_NAME)
DATASET_PATH = os.path.join(DATASETS_FOLDER_PATH, DATASET_NAME)

# %%
# SETUP
warnings.filterwarnings('ignore')
visualizer = VisualizeDataset()

# %%
dataset = pd.read_csv(DATASET_PATH)

# %%
dataset.plot('time', figsize=(12,6))

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(dataset.magnetic_field_x, dataset.magnetic_field_y, dataset.magnetic_field_z, c=dataset.magnetic_field_y, cmap="Reds")
